# %% [markdown]
# # Numba Benchmarking With Numpy Containers and Insersion Sort

# %%
import time
import random

import numba
import numpy as np
import matplotlib.pyplot as plt

# %%
nloops = 5
npoints = 10000

# %%
def generate_data(n_points):
    arr = []

    for i in range(n_points):
        num = random.randint(0, n_points)
        arr.append(num)

    arr = np.array(arr)
    return arr

# %%
def nojit_sort(a):

    for i in range(1, len(a)):

        key = a[i]
        j = i-1

        while j >= 0 and a[j] > key:

            a[j+1] = a[j]
            j -= 1

        a[j+1] = key

    return a


@numba.jit(nopython=True)
def jit_sort(a):
    for i in range(1, len(a)):

        key = a[i]
        j = i-1

        while j >= 0 and a[j] > key:

            a[j+1] = a[j]
            j -= 1

        a[j+1] = key
    
    return a

# %%
nojit_average_runtimes = []
nojit_errors = []

for npoints in [10, 30, 100, 300, 1000, 3000, 10000]:
    num_list = generate_data(npoints)

    start = time.time()
    tmp = []
    for i in range(nloops):
        loop_start = time.time()
        result = nojit_sort(num_list)
        tmp.append(time.time() - loop_start)

    runtime = time.time() - start
    average_runtime_nojit = runtime / nloops
    nojit_errors.append(np.std(np.array(tmp)))
    nojit_average_runtimes.append(average_runtime_nojit)

# %%
jit_average_runtimes = []
jit_errors = []

for npoints in  [10, 30, 100, 300, 1000, 3000, 10000]:
    num_list = generate_data(npoints)

    start = time.time()
    tmp = []
    for i in range(nloops):
        loop_start = time.time()
        result = jit_sort(num_list)
        tmp.append(time.time() - loop_start)

    runtime = time.time() - start
    average_runtime_jit = runtime / nloops
    jit_errors.append(np.std(np.array(tmp)))
    jit_average_runtimes.append(average_runtime_jit)

# %%
plt.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "font.serif": ["Computer Modern Roman"],
    "figure.figsize": [5, 3]
})

# %%
SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=MEDIUM_SIZE)  # fontsize of the figure title

# %%
fig, ax = plt.subplots()
npoints =  [10, 30, 100, 300, 1000, 3000, 10000]

ax.set_xscale("log")
ax.set_yscale("log")

ax.plot(npoints, nojit_average_runtimes, label='Numpy', marker='o')
ax.plot(npoints, jit_average_runtimes, label='Numpy + Numba', marker='o')

ax.set_xlabel('$\log (N)$')
ax.set_ylabel('$\log (t)$')

ax.legend()
plt.show()

# %% [markdown]
# #### Numba Speedup

# %%
np.array(nojit_average_runtimes)/np.array(jit_average_runtimes)
# Out:
# array([   1.63492063,   27.56      ,  222.31034483,  475.08695652,
#         858.        , 1054.4954324 , 1040.25857725])
